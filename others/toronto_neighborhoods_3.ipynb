# %% [markdown]
# <h1 align='center'>Segmenting and Clustering Neighborhoods in Toronto - Part 3</h1>

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np # handle data in vectorized
import pandas as pd # for data analysis
import requests
import json # handle json file
import matplotlib.cm as cm # handle plotting
import matplotlib.colors as colors # handle plotting
#! pip install folium
import folium # map rendering
#! pip install geopy
from geopy.geocoders import Nominatim # use to get the coordinates from a defined address
from sklearn.cluster import KMeans # algorithm use to grouping the data

# %% [markdown]
# ## Preparing Data

# %% [markdown]
# #### getting toronto dataframe from previous part

# %%
toronto_ll = pd.read_csv('../data/Toronto_Neighborhoods_Coord.csv') # importing data
print('datafame contains {} rows'.format(toronto_ll.shape[0])) # length of original dataframe
toronto_ll.head() # display the original dataframe
# Out:
# datafame contains 103 rows
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# #### filtering data - get only borough that include the word 'Toronto'

# %%
toronto = toronto_ll[toronto_ll['Borough'].str.contains('Toronto')] # ignore the row without word 'Toronto' on Borough columns
print('datafame contains {} rows'.format(toronto.shape[0])) # length of dataframe after filtering
toronto.reset_index(drop=True, inplace=True)
toronto.head() # display the resulting dataframe
# Out:
# datafame contains 39 rows
#   Postal Code           Borough                                 Neighborhood  \
# 0         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 1         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 2         M5B  Downtown Toronto                     Garden District, Ryerson
# 3         M5C  Downtown Toronto                               St. James Town
# 4         M4E      East Toronto                                  The Beaches
#
#     Latitude  Longitude
# 0  43.654260 -79.360636
# 1  43.662301 -79.389494
# 2  43.657162 -79.378937
# 3  43.651494 -79.375418
# 4  43.676357 -79.293031

# %% [markdown]
# #### the row without 'Toronto' in dataframe are filtered out and now have only 39 rows

# %% [markdown]
# ## Getting Venue Data

# %% [markdown]
# #### define credentials

# %%
CLIENT_ID = 'RANTRTMBVOQOIHLZLEXAH3CXS5WJWVEWZCO0OL0U5EA5NTAX' # foursquare id
CLIENT_SECRET = '53TB4P3VBOZTCQFMKSJ2NAXHVYI5G5KDR5OONTEMTANKW2Y3' # foursquare secret
VERSION = '20180605' # foursquare api version
RADIUS = 500 # radius from a defined coordinates
LIMIT = 100 # limiting result to less than 100

# %% [markdown]
# #### getting venue name and their categories via foursquare api

# %%
venue_list = []

# getting the information of each venue
for name, lat, lng in zip(toronto['Neighborhood'], toronto['Latitude'], toronto['Longitude']):
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, RADIUS, LIMIT) # define an url
    result = requests.get(url).json()['response']['groups'][0]['items'] # sent get requests

    # getting venues name and their categories from whole items
    for vn in result:
        venue_list.append([name, lat, lng, vn['venue']['name'], vn['venue']['categories'][0]['name']]) # put venue data into list

col = ['Neighborhood', 'Neighborhood Lat', 'Neighborhood Lon', 'Venue Name', 'Venue Categories'] # define columns name
toronto_venue = pd.DataFrame(venue_list, columns = col) # convert all list into dataframe

print('dataframe contain {} neighborhood rows, {} venues, and {} unique categories'.format(
    toronto_venue['Neighborhood'].unique().shape[0], toronto_venue.shape[0], toronto_venue['Venue Categories'].unique().shape[0])) # dataframe information

toronto_venue.head() # display the resulting dataframe
# Out:
# dataframe contain 39 neighborhood rows, 1620 venues, and 237 unique categories
#                 Neighborhood  Neighborhood Lat  Neighborhood Lon  \
# 0  Regent Park, Harbourfront          43.65426        -79.360636
# 1  Regent Park, Harbourfront          43.65426        -79.360636
# 2  Regent Park, Harbourfront          43.65426        -79.360636
# 3  Regent Park, Harbourfront          43.65426        -79.360636
# 4  Regent Park, Harbourfront          43.65426        -79.360636
#
#                  Venue Name     Venue Categories
# 0          Roselle Desserts               Bakery
# 1             Tandem Coffee          Coffee Shop
# 2    Cooper Koo Family YMCA  Distribution Center
# 3       Body Blitz Spa East                  Spa
# 4  Dominion Pub and Kitchen                  Pub

# %% [markdown]
# #### transform venue categories with one hot encoding method

# %%
# creating one hot encoding table from categories column
toronto_venue_cat = pd.get_dummies(toronto_venue['Venue Categories'])

# insert neighborhood column to the table
toronto_venue_cat.insert(0, 'Toronto Neighborhood', toronto_venue['Neighborhood'])

print('dataframe contain {} venues and {} unique categories'.format(toronto_venue_cat.shape[0], toronto_venue_cat.shape[1]-1))
#toronto_venue_cat.head()
# Out:
# dataframe contain 1620 venues and 237 unique categories

# %% [markdown]
# #### processing data to get the top ten venue categories in each borough that contain the word 'Toronto'

# %%
toronto_grouped = toronto_venue_cat.groupby(toronto_venue_cat['Toronto Neighborhood']).mean().reset_index() # frequency table

num_top_venues = 10 # get top ten venues

# define columns name
col = []
ind = ['st', 'nd', 'rd'] # indices for first three rank '1st', '2nd', '3rd'
for n in range(num_top_venues):
    if n < 3: col.append('{}{} Most Common Venue'.format(n+1, ind[n]))
    else: col.append('{}th Most Common Venue'.format(n+1))

# sorting top ten values, then get their index name (per row) and append it into a list of rows
toronto_sorted = []
for neighbor in range(len(toronto_grouped)):
    toronto_sorted.append(toronto_grouped.iloc[neighbor, 1:].sort_values(ascending=False).index[0:num_top_venues])

toronto_cluster = pd.DataFrame(toronto_sorted, columns=col) # convert a list of row into a dataframe

toronto_cluster.insert(0, 'Neighborhood', toronto['Neighborhood']) # insert neighborhood column to the table

toronto_cluster.head() # display the resulting dataframe
# Out:
#                                   Neighborhood 1st Most Common Venue  \
# 0                    Regent Park, Harbourfront           Coffee Shop
# 1  Queen's Park, Ontario Provincial Government                  Café
# 2                     Garden District, Ryerson                Garden
# 3                               St. James Town       Airport Service
# 4                                  The Beaches           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0          Cocktail Bar              Beer Bar                Bakery
# 1                Bakery           Coffee Shop        Breakfast Spot
# 2               Brewery         Burrito Place                   Spa
# 3        Airport Lounge      Airport Terminal      Sculpture Garden
# 4        Sandwich Place    Italian Restaurant                  Café
#
#   5th Most Common Venue 6th Most Common Venue  7th Most Common Venue  \
# 0           Cheese Shop    Seafood Restaurant                   Café
# 1           Yoga Studio     Convenience Store  Performing Arts Venue
# 2    Light Rail Station           Pizza Place                Butcher
# 3               Airport    Airport Food Court           Airport Gate
# 4   Japanese Restaurant           Salad Place        Bubble Tea Shop
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0            Restaurant      Greek Restaurant              Irish Pub
# 1             Pet Store          Climbing Gym             Restaurant
# 2  Fast Food Restaurant         Auto Workshop         Farmers Market
# 3              Boutique         Boat or Ferry    Rental Car Location
# 4          Burger Joint      Department Store        Thai Restaurant

# %% [markdown]
# ## Clustering

# %% [markdown]
# #### clustering data with k-means clustering algorithm

# %%
# use frequency table (toronto_grouped) as a feature and drop unnecessary columns
toronto_x = toronto_grouped.drop(['Toronto Neighborhood'], axis=1)

# clustering
cluster = 5 # number of clusters
k_means = KMeans(n_clusters=cluster, random_state=4).fit(toronto_x) # fit the model

toronto_cluster.insert(1, 'Cluster', k_means.labels_) # insert the result label into the table
toronto_cluster.head() # display the resulting dataframe
# Out:
#                                   Neighborhood  Cluster 1st Most Common Venue  \
# 0                    Regent Park, Harbourfront        0           Coffee Shop
# 1  Queen's Park, Ontario Provincial Government        0                  Café
# 2                     Garden District, Ryerson        0                Garden
# 3                               St. James Town        0       Airport Service
# 4                                  The Beaches        0           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0          Cocktail Bar              Beer Bar                Bakery
# 1                Bakery           Coffee Shop        Breakfast Spot
# 2               Brewery         Burrito Place                   Spa
# 3        Airport Lounge      Airport Terminal      Sculpture Garden
# 4        Sandwich Place    Italian Restaurant                  Café
#
#   5th Most Common Venue 6th Most Common Venue  7th Most Common Venue  \
# 0           Cheese Shop    Seafood Restaurant                   Café
# 1           Yoga Studio     Convenience Store  Performing Arts Venue
# 2    Light Rail Station           Pizza Place                Butcher
# 3               Airport    Airport Food Court           Airport Gate
# 4   Japanese Restaurant           Salad Place        Bubble Tea Shop
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0            Restaurant      Greek Restaurant              Irish Pub
# 1             Pet Store          Climbing Gym             Restaurant
# 2  Fast Food Restaurant         Auto Workshop         Farmers Market
# 3              Boutique         Boat or Ferry    Rental Car Location
# 4          Burger Joint      Department Store        Thai Restaurant

# %% [markdown]
# ## Visualizing Result

# %% [markdown]
# #### getting Toronto latitude and longitude

# %%
address = 'Toronto, Ontario' # define an address
geolocator = Nominatim(user_agent='ny_explorer')
location = geolocator.geocode(address) # getting coordinates
latitude = location.latitude # 43.6534817
longitude = location.longitude # -79.3839347

# %% [markdown]
# #### adding the map with neighborhoods and their cluster

# %%
# create the map center around 'Toronto, Ontario'
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=12) # creating map

# define color array
x = cm.rainbow(np.linspace(0, 1, cluster))
color = [colors.rgb2hex(i) for i in x] # array of colors for each cluster

for neigh, lat, lon, clus in zip(
toronto['Neighborhood'], toronto['Latitude'], toronto['Longitude'], toronto_cluster['Cluster']):
    labels=folium.Popup('{} Cluster {}'.format(neigh, clus), parse_html=True) # define labels
    folium.CircleMarker(
        location=[lat,lon], # location of each neighborhood
        popup=labels, # put label into the popup
        radius=5, # size of marker
        color=color[clus], 
        fill='blue', 
        fill_color=color[clus],
        fill_opacity=0.7,
        ).add_to(map_toronto) # add the marker into the map

map_toronto # display the map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Explore Clusters

# %% [markdown]
# #### Cluster 0 - Include most of the cafe and coffee shops

# %%
toronto_cluster[toronto_cluster['Cluster'] == 0]
# Out:
#                                          Neighborhood  Cluster  \
# 0                           Regent Park, Harbourfront        0
# 1         Queen's Park, Ontario Provincial Government        0
# 2                            Garden District, Ryerson        0
# 3                                      St. James Town        0
# 4                                         The Beaches        0
# 5                                         Berczy Park        0
# 6                                  Central Bay Street        0
# 7                                            Christie        0
# 8                            Richmond, Adelaide, King        0
# 9                        Dufferin, Dovercourt Village        0
# 10  Harbourfront East, Union Station, Toronto Islands        0
# 11                           Little Portugal, Trinity        0
# 13           Toronto Dominion Centre, Design Exchange        0
# 14       Brockton, Parkdale Village, Exhibition Place        0
# 15                     India Bazaar, The Beaches West        0
# 16                     Commerce Court, Victoria Hotel        0
# 17                                    Studio District        0
# 19                                           Roselawn        0
# 21    Forest Hill North & West, Forest Hill Road Park        0
# 22                      High Park, The Junction South        0
# 23                 North Toronto West,  Lawrence Park        0
# 24                The Annex, North Midtown, Yorkville        0
# 25                             Parkdale, Roncesvalles        0
# 28                                 Runnymede, Swansea        0
# 29                        Moore Park, Summerhill East        0
# 30          Kensington Market, Chinatown, Grange Park        0
# 31  Summerhill West, Rathnelly, South Hill, Forest...        0
# 32  CN Tower, King and Spadina, Railway Lands, Har...        0
# 33                                           Rosedale        0
# 34                                     Stn A PO Boxes        0
# 36             First Canadian Place, Underground city        0
# 37                               Church and Wellesley        0
# 38  Business reply mail Processing Centre, South C...        0
#
#    1st Most Common Venue          2nd Most Common Venue  \
# 0            Coffee Shop                   Cocktail Bar
# 1                   Café                         Bakery
# 2                 Garden                        Brewery
# 3        Airport Service                 Airport Lounge
# 4            Coffee Shop                 Sandwich Place
# 5          Grocery Store                           Café
# 6            Coffee Shop               Sushi Restaurant
# 7            Coffee Shop                           Café
# 8            Pizza Place                   Dessert Shop
# 9                   Park                    Pizza Place
# 10                Bakery                       Pharmacy
# 11           Coffee Shop                           Café
# 13        Clothing Store                    Coffee Shop
# 14           Coffee Shop                       Aquarium
# 15                  Café             Mexican Restaurant
# 16                  Park           Fast Food Restaurant
# 17                  Café  Vegetarian / Vegan Restaurant
# 19                   Bar                           Café
# 21        Clothing Store                    Coffee Shop
# 22             Gift Shop                 Breakfast Spot
# 23           Coffee Shop               Sushi Restaurant
# 24           Coffee Shop                           Park
# 25           Coffee Shop                           Café
# 28           Coffee Shop                           Café
# 29                  Café                    Coffee Shop
# 30           Coffee Shop                           Café
# 31           Coffee Shop                           Café
# 32                  Café                    Coffee Shop
# 33                   Pub                    Coffee Shop
# 34                  Café                 Sandwich Place
# 36      Greek Restaurant                    Coffee Shop
# 37           Coffee Shop                          Hotel
# 38                  Café            Japanese Restaurant
#
#      3rd Most Common Venue        4th Most Common Venue  \
# 0                 Beer Bar                       Bakery
# 1              Coffee Shop               Breakfast Spot
# 2            Burrito Place                          Spa
# 3         Airport Terminal             Sculpture Garden
# 4       Italian Restaurant                         Café
# 5                     Park                        Diner
# 6      Japanese Restaurant                   Restaurant
# 7               Restaurant                        Hotel
# 8           Sandwich Place                  Coffee Shop
# 9           Breakfast Spot               Sandwich Place
# 10               Pet Store                  Supermarket
# 11              Restaurant                        Hotel
# 13                    Café               Cosmetics Shop
# 14                    Café                        Hotel
# 15  Furniture / Home Store              Thai Restaurant
# 16             Pizza Place                   Board Shop
# 17                  Bakery                  Coffee Shop
# 19             Coffee Shop             Asian Restaurant
# 21             Yoga Studio         Fast Food Restaurant
# 22           Movie Theater  Eastern European Restaurant
# 23                   Diner                  Yoga Studio
# 24                     Pub                       Bakery
# 25              Restaurant                          Gym
# 28             Pizza Place             Sushi Restaurant
# 29               Gastropub                   Restaurant
# 30                  Bakery                   Restaurant
# 31      Italian Restaurant           Seafood Restaurant
# 32               Gastropub                       Bakery
# 33             Supermarket        Vietnamese Restaurant
# 34             Coffee Shop                  Pizza Place
# 36      Italian Restaurant               Ice Cream Shop
# 37                    Café                   Restaurant
# 38                     Bar           Italian Restaurant
#
#         5th Most Common Venue          6th Most Common Venue  \
# 0                 Cheese Shop             Seafood Restaurant
# 1                 Yoga Studio              Convenience Store
# 2          Light Rail Station                    Pizza Place
# 3                     Airport             Airport Food Court
# 4         Japanese Restaurant                    Salad Place
# 5                 Candy Store                     Baby Store
# 6                     Gay Bar                    Yoga Studio
# 7         American Restaurant                            Gym
# 8          Italian Restaurant                           Café
# 9            Department Store              Food & Drink Shop
# 10                       Café                            Bar
# 11                        Gym                    Salad Place
# 13  Middle Eastern Restaurant            Japanese Restaurant
# 14             Scenic Lookout                        Brewery
# 15                 Restaurant                      Speakeasy
# 16          Fish & Chips Shop                        Brewery
# 17      Vietnamese Restaurant             Mexican Restaurant
# 19      Vietnamese Restaurant  Vegetarian / Vegan Restaurant
# 21        Rental Car Location             Mexican Restaurant
# 22                    Dog Run             Italian Restaurant
# 23             Discount Store                            Bar
# 24                       Café                        Theater
# 25            Thai Restaurant                          Hotel
# 28                      Diner             Italian Restaurant
# 29        American Restaurant                   Cocktail Bar
# 30                       Park             Italian Restaurant
# 31                   Beer Bar                   Cocktail Bar
# 32                    Brewery            American Restaurant
# 33           Sushi Restaurant             Light Rail Station
# 34                        Pub      Middle Eastern Restaurant
# 36     Furniture / Home Store                     Restaurant
# 37         Italian Restaurant             Seafood Restaurant
# 38                  Bookstore                     Restaurant
#
#     7th Most Common Venue 8th Most Common Venue      9th Most Common Venue  \
# 0                    Café            Restaurant           Greek Restaurant
# 1   Performing Arts Venue             Pet Store               Climbing Gym
# 2                 Butcher  Fast Food Restaurant              Auto Workshop
# 3            Airport Gate              Boutique              Boat or Ferry
# 4         Bubble Tea Shop          Burger Joint           Department Store
# 5              Restaurant    Athletics & Sports         Italian Restaurant
# 6         Bubble Tea Shop          Burger Joint   Mediterranean Restaurant
# 7      Italian Restaurant   Japanese Restaurant         Seafood Restaurant
# 8        Sushi Restaurant                   Gym                      Diner
# 9       Convenience Store                 Hotel                        Gym
# 10       Recording Studio                  Bank  Middle Eastern Restaurant
# 11             Steakhouse      Asian Restaurant        American Restaurant
# 13        Bubble Tea Shop    Italian Restaurant                    Theater
# 14    Sporting Goods Shop            Restaurant        Fried Chicken Joint
# 15            Flea Market                   Bar                     Bakery
# 16           Liquor Store            Restaurant              Burrito Place
# 17           Dessert Shop                  Park              Grocery Store
# 19             Restaurant           Men's Store        Japanese Restaurant
# 21             Shoe Store            Restaurant                       Café
# 22                    Bar                  Bank                 Restaurant
# 23               Beer Bar         Smoothie Shop           Sculpture Garden
# 24             Restaurant        Breakfast Spot                Yoga Studio
# 25          Deli / Bodega      Sushi Restaurant                  Bookstore
# 28                    Pub            Restaurant               Gourmet Shop
# 29         Lingerie Store   Moroccan Restaurant                   Creperie
# 30                    Pub           Pizza Place                 Playground
# 31             Restaurant                 Hotel        Japanese Restaurant
# 32           Neighborhood        Sandwich Place                Cheese Shop
# 33                   Bank          Liquor Store        American Restaurant
# 34              BBQ Joint     Indian Restaurant             History Museum
# 36              Bookstore       Bubble Tea Shop          Indian Restaurant
# 37            Salad Place   American Restaurant        Japanese Restaurant
# 38                 Bakery    Chinese Restaurant                        Pub
#
#            10th Most Common Venue
# 0                       Irish Pub
# 1                      Restaurant
# 2                  Farmers Market
# 3             Rental Car Location
# 4                 Thai Restaurant
# 5                       Nightclub
# 6                             Pub
# 7   Vegetarian / Vegan Restaurant
# 8               Indian Restaurant
# 9                    Concert Hall
# 10                           Park
# 11             Seafood Restaurant
# 13               Ramen Restaurant
# 14                            Bar
# 15           Fast Food Restaurant
# 16             Italian Restaurant
# 17                    Pizza Place
# 19                      Juice Bar
# 21            Sporting Goods Shop
# 22                   Dessert Shop
# 23                 Sandwich Place
# 24                     Shoe Store
# 25                    Pizza Place
# 28              Fish & Chips Shop
# 29                          Hotel
# 30                 Farmers Market
# 31                    Cheese Shop
# 32                      Pet Store
# 33                     Restaurant
# 34                   Burger Joint
# 36                            Pub
# 37                       Beer Bar
# 38               Sushi Restaurant

# %% [markdown]
# #### Cluster 1 - Include park and some outdoor places

# %%
toronto_cluster[toronto_cluster['Cluster'] == 1]
# Out:
#                     Neighborhood  Cluster 1st Most Common Venue  \
# 12  The Danforth West, Riverdale        1                 Trail
# 20              Davisville North        1                  Park
# 26                    Davisville        1                  Park
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 12                  Park              Bus Line         Jewelry Store
# 20            Restaurant            Playground            Donut Shop
# 26            Playground                 Trail          Cupcake Shop
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 12      Sushi Restaurant   Dumpling Restaurant            Donut Shop
# 20      Doner Restaurant               Dog Run   Distribution Center
# 26   Dumpling Restaurant            Donut Shop      Doner Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 12      Doner Restaurant               Dog Run    Distribution Center
# 20        Discount Store                 Diner     Dim Sum Restaurant
# 26               Dog Run   Distribution Center         Discount Store

# %% [markdown]
# #### Cluster 2 - Include some outdoor specific places

# %%
toronto_cluster[toronto_cluster['Cluster'] == 2]
# Out:
#                    Neighborhood  Cluster 1st Most Common Venue  \
# 35  St. James Town, Cabbagetown        2     Health Food Store
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 35          Neighborhood      Asian Restaurant                   Pub
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 35                 Trail      Department Store          Dessert Shop
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 35    Dim Sum Restaurant                 Diner            Yoga Studio

# %% [markdown]
# #### Cluster 3 - Include some specific places

# %%
toronto_cluster[toronto_cluster['Cluster'] == 3]
# Out:
#                       Neighborhood  Cluster 1st Most Common Venue  \
# 27  University of Toronto, Harbord        3                Garden
#
#    2nd Most Common Venue 3rd Most Common Venue        4th Most Common Venue  \
# 27           Yoga Studio          Dance Studio  Eastern European Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 27   Dumpling Restaurant            Donut Shop      Doner Restaurant
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 27               Dog Run   Distribution Center         Discount Store

# %% [markdown]
# #### Cluster 4 - Include some outdoor places

# %%
toronto_cluster[toronto_cluster['Cluster'] == 4]
# Out:
#      Neighborhood  Cluster 1st Most Common Venue 2nd Most Common Venue  \
# 18  Lawrence Park        4                  Park              Bus Line
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 18           Swim School                Lawyer  Colombian Restaurant
#
#    6th Most Common Venue        7th Most Common Venue 8th Most Common Venue  \
# 18           College Gym  Eastern European Restaurant   Dumpling Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 18            Donut Shop       Doner Restaurant
